# %%
from textblob import TextBlob
import matplotlib.pyplot as plt
import requests, math, time
import csv, pathlib
import pandas as pd
import os
import openai
import json
import seaborn as sns
import json
import sys
import warnings
import spacy
from spacy.lang.en.examples import sentences 
import en_core_web_sm
from wordcloud import WordCloud

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
print("This program uses an ML natural language model (GPT-3) to summarize and analyze articles in the NYT\nto summarize and do sentiment analysis on a given subject, person, or location (or any other keyword) over time")
print("\nYou can input your query using natural language like this: \nSearch all articles about Michael Jackson from 1990 to his death")
print("\nSearch all articles about Enron since its IPO up to its collapse")

print("\nNote: If you want detailed and accurate answers, it is better to include the dates in the query.")
# Out:
# This program uses an ML natural language model (GPT-3) to summarize and analyze articles in the NYT
# to summarize and do sentiment analysis on a given subject, person, or location (or any other keyword) over time
#
# You can input your query using natural language like this:
# Search all articles about Michael Jackson from 1990 to his death
#
# Search all articles about Enron since its IPO up to its collapse
#
# Note: If you want detailed and accurate answers, it is better to include the dates in the query.

# %%
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

# %%
# Open the JSON file in read mode (OpenAI)
with open("..//api_key.json", "r") as f:
    # Load the JSON data from the file
    data = json.load(f)
    # Get the API key from the JSON data
    api_key = data["api_key"]

# Set the API key
openai.api_key = api_key

# %%
#Open the JSON files in read mode (NYT API Key)
with open("..//nyt_key.json", "r") as f:
    # Load the JSON data from the file
    data = json.load(f)
    # Get the API key from the JSON data
    api_key = data["api_key"]

# Set the API key
nyt_key = api_key

# %%
query = str(input("Enter the search query: "))
# Out:
# Enter the search query: articles about juan manuel santos since the peace referendum until the end of his presidency in colombia

# %%
#turning the response from natural language to objects that are readable by the NYT API
response_keyword = openai.Completion.create(
  model="text-davinci-003",
  prompt="Find the main keyword (a name, a location, etc) from this query and nothing else: " + query,
  temperature=0.7,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

keyword = response_keyword.choices[0].text

def remove_leading_trailing_spaces(obj):
    # Use the strip() method to remove leading and trailing spaces
    return obj.strip()

keyword = remove_leading_trailing_spaces(keyword)

response_date = openai.Completion.create(
  model="text-davinci-003",
  prompt="In number format, and adding no extra text tell me the year, month, day (YYYYMMDD) relevant to this query (there should be two dates, beggining and end separated by a single comma). If no indication of time in query, output NA. Years start on 0101 and end 1231. If no end date, add today's date: " + query,
  temperature=0.5,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

dates = response_date.choices[0].text

# Split the input string into a list of dates
dates = dates.split(",")

# Assign the first date to begin_date
begin_date = dates[0]

# Assign the second date to end_date
end_date = dates[1]

# We need to remove all spaces and non-numeric characters
begin_date = ''.join([c for c in begin_date if c.isdigit()])
end_date = ''.join([c for c in end_date if c.isdigit()])

# %%
# Adding + signs for entries with multiple words
def format_keyword(keyword):
    # Split the keyword into a list of words
    words = keyword.split()
    
    # Join the words with a + separator
    formatted_keyword = "+".join(words)
    
    return formatted_keyword

keyword = format_keyword(keyword)

# %%
#checking out outputs
print(keyword)
print(begin_date)
print(end_date)
# Out:
# Juan+Manuel+Santos
# 20160505
# 20180512

# %%
# GETTING THE NUMBER OF HITS FIRST (WE DO NOT WANT TO EXCEED API CALL LIMIT TOO QUICKLY)
def get_num_hits(api_key, keyword, begin_date, end_date):
    # Set up the parameters for the API request
    base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={keyword}'

    params = {
        'api-key': api_key,
        'q': keyword,
        'page': 0,
        'begin_date': begin_date,
        'end_date': end_date
    }
    response = requests.get(base_url, params=params)
    data = response.json()

    # Retrieve the number of hits
    num_hits = data['response']['meta']['hits']

    return num_hits

# %%
get_num_hits(nyt_key, keyword, begin_date, end_date)
# Out:
# 126

# %%
# VERSION WITH ERROR HANDLING
# Version of NYT article search with the ability to run unlimited articles (NYT API limits to 100 hits per call)
def search_articles(api_key, keyword, begin_date, end_date):
    # Set up the parameters for the API request
    base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={keyword}'

    # Create an empty dataframe to store the results
    df = pd.DataFrame()

    # Set the number of articles to retrieve
    num_articles = 0

    # Perform the API request for each page
    page = 0
    while True:
        params = {
            'api-key': api_key,
            'q': keyword,
            'page': page,
            'begin_date': begin_date,
            'end_date': end_date
        }
        response = requests.get(base_url, params=params)
        if response.status_code != 200:
            raise Exception(f'Request failed with status code {response.status_code}')
        data = response.json()

        # Check if the response has the expected format
        if 'response' not in data or 'docs' not in data['response']:
            raise Exception(f'Unexpected response format: {data}')

        # Add the articles to the dataframe
        for article in data['response']['docs']:
            df = df.append(article, ignore_index=True)
            num_articles += 1

        # Check if there are more articles available
        if len(data['response']['docs']) == 0:
            break

        # Add a delay to avoid exceeding the API rate limit
        # The limit for the NYT API per docs is 6 seconds per request, 10 per minute
        #(https://developer.nytimes.com/faq#:~:text=Yes%2C%20there%20are%20two%20rate%20limits%20per%20API%3A,higher%20rate%20limit%2C%20please%20contact%20us%20at%20code%40nytimes.com.)
        time.sleep(6)
        page += 1
    
    return df

# %%
# Comprehensive search
# Can take anywhere from a few seconds to a few minutes to run depending on the number of hits (articles)
# check cell above to see how many hits there are
df = search_articles(nyt_key, keyword, begin_date, end_date)

# %%
df
# Out:
#                                               abstract  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2018/04/10/world/ameri...
# 1    https://www.nytimes.com/2018/04/05/opinion/col...
# 2    https://www.nytimes.com/2018/03/12/world/ameri...
# 3    https://www.nytimes.com/2018/03/10/us/politics...
# 4    https://www.nytimes.com/2018/02/17/world/ameri...
# ..                                                 ...
# 121  https://www.nytimes.com/2016/11/09/world/europ...
# 122  https://www.nytimes.com/2018/05/08/travel/chil...
# 123  https://www.nytimes.com/2016/09/11/world/ameri...
# 124  https://www.nytimes.com/2017/10/06/world/nobel...
# 125  https://www.nytimes.com/2016/11/25/opinion/col...
#
#                                                snippet  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                         lead_paragraph  \
# 0    MEDELLÍN, Colombia — A former guerrilla peace ...
# 1    Washington — A nation’s transition from confli...
# 2    MEDELLÍN, Colombia — Colombians elected a divi...
# 3    President Trump will make the first visit of h...
# 4    CÚCUTA, Colombia — For the past three weeks, W...
# ..                                                 ...
# 121  The election of Donald J. Trump as president o...
# 122  Our columnist, Jada Yuan, is visiting each des...
# 123  CALABAZO, Colombia — Skinny but imposing with ...
# 124  “For their efforts to end the use of sexual vi...
# 125                                     To the Editor:
#
#                            source  \
# 0              The New York Times
# 1    International New York Times
# 2              The New York Times
# 3              The New York Times
# 4              The New York Times
# ..                            ...
# 121            The New York Times
# 122            The New York Times
# 123            The New York Times
# 124            The New York Times
# 125            The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 121                                                 []
# 122  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 123  [{'rank': 0, 'subtype': 'square320', 'caption'...
# 124  [{'rank': 0, 'subtype': 'hpLarge', 'caption': ...
# 125                                                 []
#
#                                               headline  \
# 0    {'main': 'Former Colombian Rebel Commander Is ...
# 1    {'main': 'Colombia’s Imperiled Transition', 'k...
# 2    {'main': 'Colombian Election Brings Divided Co...
# 3    {'main': 'Trump to Make First Visit as Preside...
# 4    {'main': 'In Colombia Border Town, Desperate V...
# ..                                                 ...
# 121  {'main': 'Across the World, Shock and Uncertai...
# 122  {'main': 'The 52 Places Traveler: In Chile, a ...
# 123  {'main': 'The Secret History of Colombia’s Par...
# 124  {'main': 'Nobel Peace Prize Winners Throughout...
# 125  {'main': 'Colombia’s Peace Agreement', 'kicker...
#
#                                               keywords  \
# 0    [{'name': 'persons', 'value': 'Hernandez, Seus...
# 1    [{'name': 'organizations', 'value': 'Revolutio...
# 2    [{'name': 'glocations', 'value': 'Colombia', '...
# 3    [{'name': 'subject', 'value': 'United States I...
# 4    [{'name': 'glocations', 'value': 'Colombia', '...
# ..                                                 ...
# 121  [{'name': 'subject', 'value': 'Presidential El...
# 122  [{'name': 'glocations', 'value': 'Chile', 'ran...
# 123  [{'name': 'glocations', 'value': 'Colombia', '...
# 124  [{'name': 'subject', 'value': 'Nobel Prizes', ...
# 125  [{'name': 'glocations', 'value': 'Colombia', '...
#
#                      pub_date document_type   news_desk section_name  \
# 0    2018-04-10T13:10:44+0000       article     Foreign        World
# 1    2018-04-05T09:45:04+0000       article        OpEd      Opinion
# 2    2018-03-12T04:52:50+0000       article     Foreign        World
# 3    2018-03-10T17:17:43+0000       article  Washington         U.S.
# 4    2018-02-17T10:00:28+0000       article     Foreign        World
# ..                        ...           ...         ...          ...
# 121  2016-11-09T06:35:17+0000       article     Foreign        World
# 122  2018-05-08T09:00:12+0000       article      Travel       Travel
# 123  2016-09-10T14:03:46+0000       article     Foreign        World
# 124  2017-10-06T10:15:10+0000       article     Foreign        World
# 125  2016-11-25T08:21:03+0000       article     Letters      Opinion
#
#     subsection_name                                             byline  \
# 0          Americas  {'original': 'By Nicholas Casey', 'person': [{...
# 1               NaN  {'original': 'By Adam Isacson', 'person': [{'f...
# 2          Americas  {'original': 'By Nicholas Casey', 'person': [{...
# 3          Politics  {'original': 'By Maggie Haberman', 'person': [...
# 4          Americas  {'original': 'By Joe Parkin Daniels', 'person'...
# ..              ...                                                ...
# 121          Europe  {'original': 'By The New York Times', 'person'...
# 122             NaN  {'original': 'By Jada Yuan', 'person': [{'firs...
# 123        Americas  {'original': 'By Deborah Sontag', 'person': [{...
# 124             NaN  {'original': 'By Mona Boshnaq, Sewell Chan, Li...
# 125             NaN  {'original': None, 'person': [], 'organization...
#
#     type_of_material                                                _id  \
# 0               News  nyt://article/81f3db41-e085-5080-8440-aa52b0c2...
# 1              Op-Ed  nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...
# 2               News  nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...
# 3               News  nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...
# 4               News  nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...
# ..               ...                                                ...
# 121             News  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...
# 122             News  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...
# 123             News  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...
# 124             News  nyt://article/334d25c3-2380-5065-87cb-68a8472e...
# 125           Letter  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...
#
#      word_count                                                uri print_page  \
# 0           642  nyt://article/81f3db41-e085-5080-8440-aa52b0c2...        NaN
# 1          1111  nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...        NaN
# 2           519  nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...         10
# 3           467  nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...         12
# 4          1305  nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...          5
# ..          ...                                                ...        ...
# 121        2703  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...        NaN
# 122        2206  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...          6
# 123        7366  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...          1
# 124        3579  nyt://article/334d25c3-2380-5065-87cb-68a8472e...        NaN
# 125         220  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...         26
#
#     print_section
# 0             NaN
# 1             NaN
# 2               A
# 3               A
# 4               A
# ..            ...
# 121           NaN
# 122            TR
# 123             A
# 124           NaN
# 125             A
#
# [126 rows x 20 columns]

# %% [markdown]
# #NO NEED TO RUN THIS
# #Version of NYT article search that returns the first 100 articles (faster but not comprehensive)
# {def search_articles(api_key, keyword, begin_date, end_date):
#     # Set up the parameters for the API request
#     base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={keyword}'
#
#     # Create an empty dataframe to store the results
#     df = pd.DataFrame()
#
#     # Set the number of pages to retrieve
#     num_pages = 10
#
#     # Perform the API request for each page
#     for page in range(num_pages):
#         params = {
#             'api-key': nyt_key,
#             'q': keyword,
#             'page': page,
#             'begin_date': begin_date,
#             'end_date': end_date
#         }
#         response = requests.get(base_url, params=params)
#         data = response.json()
#
#         # Add the articles to the dataframe
#         for article in data['response']['docs']:
#             df = df.append(article, ignore_index=True)
#
#     return df}

# %% [markdown]
# #NO NEED TO RUN THIS
# #Testing limited search
# df = search_articles(nyt_key, keyword, begin_date, end_date)

# %%
base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={keyword}'

if begin_date:
    base_url += f'&begin_date={begin_date}'
if end_date:
    base_url += f'&end_date={end_date}'
    
    
base_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Juan+Manuel+Santos&begin_date=20160505&end_date=20180512'

# %%
df
# Out:
#                                               abstract  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2018/04/10/world/ameri...
# 1    https://www.nytimes.com/2018/04/05/opinion/col...
# 2    https://www.nytimes.com/2018/03/12/world/ameri...
# 3    https://www.nytimes.com/2018/03/10/us/politics...
# 4    https://www.nytimes.com/2018/02/17/world/ameri...
# ..                                                 ...
# 121  https://www.nytimes.com/2016/11/09/world/europ...
# 122  https://www.nytimes.com/2018/05/08/travel/chil...
# 123  https://www.nytimes.com/2016/09/11/world/ameri...
# 124  https://www.nytimes.com/2017/10/06/world/nobel...
# 125  https://www.nytimes.com/2016/11/25/opinion/col...
#
#                                                snippet  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                         lead_paragraph  \
# 0    MEDELLÍN, Colombia — A former guerrilla peace ...
# 1    Washington — A nation’s transition from confli...
# 2    MEDELLÍN, Colombia — Colombians elected a divi...
# 3    President Trump will make the first visit of h...
# 4    CÚCUTA, Colombia — For the past three weeks, W...
# ..                                                 ...
# 121  The election of Donald J. Trump as president o...
# 122  Our columnist, Jada Yuan, is visiting each des...
# 123  CALABAZO, Colombia — Skinny but imposing with ...
# 124  “For their efforts to end the use of sexual vi...
# 125                                     To the Editor:
#
#                            source  \
# 0              The New York Times
# 1    International New York Times
# 2              The New York Times
# 3              The New York Times
# 4              The New York Times
# ..                            ...
# 121            The New York Times
# 122            The New York Times
# 123            The New York Times
# 124            The New York Times
# 125            The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 121                                                 []
# 122  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 123  [{'rank': 0, 'subtype': 'square320', 'caption'...
# 124  [{'rank': 0, 'subtype': 'hpLarge', 'caption': ...
# 125                                                 []
#
#                                               headline  \
# 0    {'main': 'Former Colombian Rebel Commander Is ...
# 1    {'main': 'Colombia’s Imperiled Transition', 'k...
# 2    {'main': 'Colombian Election Brings Divided Co...
# 3    {'main': 'Trump to Make First Visit as Preside...
# 4    {'main': 'In Colombia Border Town, Desperate V...
# ..                                                 ...
# 121  {'main': 'Across the World, Shock and Uncertai...
# 122  {'main': 'The 52 Places Traveler: In Chile, a ...
# 123  {'main': 'The Secret History of Colombia’s Par...
# 124  {'main': 'Nobel Peace Prize Winners Throughout...
# 125  {'main': 'Colombia’s Peace Agreement', 'kicker...
#
#                                               keywords  \
# 0    [{'name': 'persons', 'value': 'Hernandez, Seus...
# 1    [{'name': 'organizations', 'value': 'Revolutio...
# 2    [{'name': 'glocations', 'value': 'Colombia', '...
# 3    [{'name': 'subject', 'value': 'United States I...
# 4    [{'name': 'glocations', 'value': 'Colombia', '...
# ..                                                 ...
# 121  [{'name': 'subject', 'value': 'Presidential El...
# 122  [{'name': 'glocations', 'value': 'Chile', 'ran...
# 123  [{'name': 'glocations', 'value': 'Colombia', '...
# 124  [{'name': 'subject', 'value': 'Nobel Prizes', ...
# 125  [{'name': 'glocations', 'value': 'Colombia', '...
#
#                      pub_date document_type   news_desk section_name  \
# 0    2018-04-10T13:10:44+0000       article     Foreign        World
# 1    2018-04-05T09:45:04+0000       article        OpEd      Opinion
# 2    2018-03-12T04:52:50+0000       article     Foreign        World
# 3    2018-03-10T17:17:43+0000       article  Washington         U.S.
# 4    2018-02-17T10:00:28+0000       article     Foreign        World
# ..                        ...           ...         ...          ...
# 121  2016-11-09T06:35:17+0000       article     Foreign        World
# 122  2018-05-08T09:00:12+0000       article      Travel       Travel
# 123  2016-09-10T14:03:46+0000       article     Foreign        World
# 124  2017-10-06T10:15:10+0000       article     Foreign        World
# 125  2016-11-25T08:21:03+0000       article     Letters      Opinion
#
#     subsection_name                                             byline  \
# 0          Americas  {'original': 'By Nicholas Casey', 'person': [{...
# 1               NaN  {'original': 'By Adam Isacson', 'person': [{'f...
# 2          Americas  {'original': 'By Nicholas Casey', 'person': [{...
# 3          Politics  {'original': 'By Maggie Haberman', 'person': [...
# 4          Americas  {'original': 'By Joe Parkin Daniels', 'person'...
# ..              ...                                                ...
# 121          Europe  {'original': 'By The New York Times', 'person'...
# 122             NaN  {'original': 'By Jada Yuan', 'person': [{'firs...
# 123        Americas  {'original': 'By Deborah Sontag', 'person': [{...
# 124             NaN  {'original': 'By Mona Boshnaq, Sewell Chan, Li...
# 125             NaN  {'original': None, 'person': [], 'organization...
#
#     type_of_material                                                _id  \
# 0               News  nyt://article/81f3db41-e085-5080-8440-aa52b0c2...
# 1              Op-Ed  nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...
# 2               News  nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...
# 3               News  nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...
# 4               News  nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...
# ..               ...                                                ...
# 121             News  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...
# 122             News  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...
# 123             News  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...
# 124             News  nyt://article/334d25c3-2380-5065-87cb-68a8472e...
# 125           Letter  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...
#
#      word_count                                                uri print_page  \
# 0           642  nyt://article/81f3db41-e085-5080-8440-aa52b0c2...        NaN
# 1          1111  nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...        NaN
# 2           519  nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...         10
# 3           467  nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...         12
# 4          1305  nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...          5
# ..          ...                                                ...        ...
# 121        2703  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...        NaN
# 122        2206  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...          6
# 123        7366  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...          1
# 124        3579  nyt://article/334d25c3-2380-5065-87cb-68a8472e...        NaN
# 125         220  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...         26
#
#     print_section
# 0             NaN
# 1             NaN
# 2               A
# 3               A
# 4               A
# ..            ...
# 121           NaN
# 122            TR
# 123             A
# 124           NaN
# 125             A
#
# [126 rows x 20 columns]

# %%
# function to reformat dates
def reformat_dates(data):
    data['pub_date'] = pd.to_datetime(data['pub_date'])
    data['pub_date'] = data['pub_date'].dt.date
    return data

# %%
# reformatting dates
reformat_dates(df)
# Out:
#                                               abstract  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2018/04/10/world/ameri...
# 1    https://www.nytimes.com/2018/04/05/opinion/col...
# 2    https://www.nytimes.com/2018/03/12/world/ameri...
# 3    https://www.nytimes.com/2018/03/10/us/politics...
# 4    https://www.nytimes.com/2018/02/17/world/ameri...
# ..                                                 ...
# 121  https://www.nytimes.com/2016/11/09/world/europ...
# 122  https://www.nytimes.com/2018/05/08/travel/chil...
# 123  https://www.nytimes.com/2016/09/11/world/ameri...
# 124  https://www.nytimes.com/2017/10/06/world/nobel...
# 125  https://www.nytimes.com/2016/11/25/opinion/col...
#
#                                                snippet  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                         lead_paragraph  \
# 0    MEDELLÍN, Colombia — A former guerrilla peace ...
# 1    Washington — A nation’s transition from confli...
# 2    MEDELLÍN, Colombia — Colombians elected a divi...
# 3    President Trump will make the first visit of h...
# 4    CÚCUTA, Colombia — For the past three weeks, W...
# ..                                                 ...
# 121  The election of Donald J. Trump as president o...
# 122  Our columnist, Jada Yuan, is visiting each des...
# 123  CALABAZO, Colombia — Skinny but imposing with ...
# 124  “For their efforts to end the use of sexual vi...
# 125                                     To the Editor:
#
#                            source  \
# 0              The New York Times
# 1    International New York Times
# 2              The New York Times
# 3              The New York Times
# 4              The New York Times
# ..                            ...
# 121            The New York Times
# 122            The New York Times
# 123            The New York Times
# 124            The New York Times
# 125            The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 121                                                 []
# 122  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 123  [{'rank': 0, 'subtype': 'square320', 'caption'...
# 124  [{'rank': 0, 'subtype': 'hpLarge', 'caption': ...
# 125                                                 []
#
#                                               headline  \
# 0    {'main': 'Former Colombian Rebel Commander Is ...
# 1    {'main': 'Colombia’s Imperiled Transition', 'k...
# 2    {'main': 'Colombian Election Brings Divided Co...
# 3    {'main': 'Trump to Make First Visit as Preside...
# 4    {'main': 'In Colombia Border Town, Desperate V...
# ..                                                 ...
# 121  {'main': 'Across the World, Shock and Uncertai...
# 122  {'main': 'The 52 Places Traveler: In Chile, a ...
# 123  {'main': 'The Secret History of Colombia’s Par...
# 124  {'main': 'Nobel Peace Prize Winners Throughout...
# 125  {'main': 'Colombia’s Peace Agreement', 'kicker...
#
#                                               keywords    pub_date  \
# 0    [{'name': 'persons', 'value': 'Hernandez, Seus...  2018-04-10
# 1    [{'name': 'organizations', 'value': 'Revolutio...  2018-04-05
# 2    [{'name': 'glocations', 'value': 'Colombia', '...  2018-03-12
# 3    [{'name': 'subject', 'value': 'United States I...  2018-03-10
# 4    [{'name': 'glocations', 'value': 'Colombia', '...  2018-02-17
# ..                                                 ...         ...
# 121  [{'name': 'subject', 'value': 'Presidential El...  2016-11-09
# 122  [{'name': 'glocations', 'value': 'Chile', 'ran...  2018-05-08
# 123  [{'name': 'glocations', 'value': 'Colombia', '...  2016-09-10
# 124  [{'name': 'subject', 'value': 'Nobel Prizes', ...  2017-10-06
# 125  [{'name': 'glocations', 'value': 'Colombia', '...  2016-11-25
#
#     document_type   news_desk section_name subsection_name  \
# 0         article     Foreign        World        Americas
# 1         article        OpEd      Opinion             NaN
# 2         article     Foreign        World        Americas
# 3         article  Washington         U.S.        Politics
# 4         article     Foreign        World        Americas
# ..            ...         ...          ...             ...
# 121       article     Foreign        World          Europe
# 122       article      Travel       Travel             NaN
# 123       article     Foreign        World        Americas
# 124       article     Foreign        World             NaN
# 125       article     Letters      Opinion             NaN
#
#                                                 byline type_of_material  \
# 0    {'original': 'By Nicholas Casey', 'person': [{...             News
# 1    {'original': 'By Adam Isacson', 'person': [{'f...            Op-Ed
# 2    {'original': 'By Nicholas Casey', 'person': [{...             News
# 3    {'original': 'By Maggie Haberman', 'person': [...             News
# 4    {'original': 'By Joe Parkin Daniels', 'person'...             News
# ..                                                 ...              ...
# 121  {'original': 'By The New York Times', 'person'...             News
# 122  {'original': 'By Jada Yuan', 'person': [{'firs...             News
# 123  {'original': 'By Deborah Sontag', 'person': [{...             News
# 124  {'original': 'By Mona Boshnaq, Sewell Chan, Li...             News
# 125  {'original': None, 'person': [], 'organization...           Letter
#
#                                                    _id  word_count  \
# 0    nyt://article/81f3db41-e085-5080-8440-aa52b0c2...         642
# 1    nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...        1111
# 2    nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...         519
# 3    nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...         467
# 4    nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...        1305
# ..                                                 ...         ...
# 121  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...        2703
# 122  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...        2206
# 123  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...        7366
# 124  nyt://article/334d25c3-2380-5065-87cb-68a8472e...        3579
# 125  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...         220
#
#                                                    uri print_page  \
# 0    nyt://article/81f3db41-e085-5080-8440-aa52b0c2...        NaN
# 1    nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...        NaN
# 2    nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...         10
# 3    nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...         12
# 4    nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...          5
# ..                                                 ...        ...
# 121  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...        NaN
# 122  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...          6
# 123  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...          1
# 124  nyt://article/334d25c3-2380-5065-87cb-68a8472e...        NaN
# 125  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...         26
#
#     print_section
# 0             NaN
# 1             NaN
# 2               A
# 3               A
# 4               A
# ..            ...
# 121           NaN
# 122            TR
# 123             A
# 124           NaN
# 125             A
#
# [126 rows x 20 columns]

# %%
#Sentiment Analysis and Seaborn code

# Combine the three text columns into one
df["text"] = df["abstract"].astype(str) + df["lead_paragraph"].astype(str) + df["byline"].astype(str)

# Create a new column for the sentiment scores with the TextBlob (NLP)
df["sentiment"] = df["text"].apply(lambda x: TextBlob(x).sentiment.polarity)

# Format the pub_date column as a date
df["pub_date"] = pd.to_datetime(df["pub_date"])

# Plot the sentiment scores over time
#sns.lineplot(x="pub_date", y="sentiment", data=df)

# %%
df
# Out:
#                                               abstract  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2018/04/10/world/ameri...
# 1    https://www.nytimes.com/2018/04/05/opinion/col...
# 2    https://www.nytimes.com/2018/03/12/world/ameri...
# 3    https://www.nytimes.com/2018/03/10/us/politics...
# 4    https://www.nytimes.com/2018/02/17/world/ameri...
# ..                                                 ...
# 121  https://www.nytimes.com/2016/11/09/world/europ...
# 122  https://www.nytimes.com/2018/05/08/travel/chil...
# 123  https://www.nytimes.com/2016/09/11/world/ameri...
# 124  https://www.nytimes.com/2017/10/06/world/nobel...
# 125  https://www.nytimes.com/2016/11/25/opinion/col...
#
#                                                snippet  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                         lead_paragraph  \
# 0    MEDELLÍN, Colombia — A former guerrilla peace ...
# 1    Washington — A nation’s transition from confli...
# 2    MEDELLÍN, Colombia — Colombians elected a divi...
# 3    President Trump will make the first visit of h...
# 4    CÚCUTA, Colombia — For the past three weeks, W...
# ..                                                 ...
# 121  The election of Donald J. Trump as president o...
# 122  Our columnist, Jada Yuan, is visiting each des...
# 123  CALABAZO, Colombia — Skinny but imposing with ...
# 124  “For their efforts to end the use of sexual vi...
# 125                                     To the Editor:
#
#                            source  \
# 0              The New York Times
# 1    International New York Times
# 2              The New York Times
# 3              The New York Times
# 4              The New York Times
# ..                            ...
# 121            The New York Times
# 122            The New York Times
# 123            The New York Times
# 124            The New York Times
# 125            The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 121                                                 []
# 122  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 123  [{'rank': 0, 'subtype': 'square320', 'caption'...
# 124  [{'rank': 0, 'subtype': 'hpLarge', 'caption': ...
# 125                                                 []
#
#                                               headline  \
# 0    {'main': 'Former Colombian Rebel Commander Is ...
# 1    {'main': 'Colombia’s Imperiled Transition', 'k...
# 2    {'main': 'Colombian Election Brings Divided Co...
# 3    {'main': 'Trump to Make First Visit as Preside...
# 4    {'main': 'In Colombia Border Town, Desperate V...
# ..                                                 ...
# 121  {'main': 'Across the World, Shock and Uncertai...
# 122  {'main': 'The 52 Places Traveler: In Chile, a ...
# 123  {'main': 'The Secret History of Colombia’s Par...
# 124  {'main': 'Nobel Peace Prize Winners Throughout...
# 125  {'main': 'Colombia’s Peace Agreement', 'kicker...
#
#                                               keywords   pub_date  \
# 0    [{'name': 'persons', 'value': 'Hernandez, Seus... 2018-04-10
# 1    [{'name': 'organizations', 'value': 'Revolutio... 2018-04-05
# 2    [{'name': 'glocations', 'value': 'Colombia', '... 2018-03-12
# 3    [{'name': 'subject', 'value': 'United States I... 2018-03-10
# 4    [{'name': 'glocations', 'value': 'Colombia', '... 2018-02-17
# ..                                                 ...        ...
# 121  [{'name': 'subject', 'value': 'Presidential El... 2016-11-09
# 122  [{'name': 'glocations', 'value': 'Chile', 'ran... 2018-05-08
# 123  [{'name': 'glocations', 'value': 'Colombia', '... 2016-09-10
# 124  [{'name': 'subject', 'value': 'Nobel Prizes', ... 2017-10-06
# 125  [{'name': 'glocations', 'value': 'Colombia', '... 2016-11-25
#
#     document_type  ... subsection_name  \
# 0         article  ...        Americas
# 1         article  ...             NaN
# 2         article  ...        Americas
# 3         article  ...        Politics
# 4         article  ...        Americas
# ..            ...  ...             ...
# 121       article  ...          Europe
# 122       article  ...             NaN
# 123       article  ...        Americas
# 124       article  ...             NaN
# 125       article  ...             NaN
#
#                                                 byline type_of_material  \
# 0    {'original': 'By Nicholas Casey', 'person': [{...             News
# 1    {'original': 'By Adam Isacson', 'person': [{'f...            Op-Ed
# 2    {'original': 'By Nicholas Casey', 'person': [{...             News
# 3    {'original': 'By Maggie Haberman', 'person': [...             News
# 4    {'original': 'By Joe Parkin Daniels', 'person'...             News
# ..                                                 ...              ...
# 121  {'original': 'By The New York Times', 'person'...             News
# 122  {'original': 'By Jada Yuan', 'person': [{'firs...             News
# 123  {'original': 'By Deborah Sontag', 'person': [{...             News
# 124  {'original': 'By Mona Boshnaq, Sewell Chan, Li...             News
# 125  {'original': None, 'person': [], 'organization...           Letter
#
#                                                    _id word_count  \
# 0    nyt://article/81f3db41-e085-5080-8440-aa52b0c2...        642
# 1    nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...       1111
# 2    nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...        519
# 3    nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...        467
# 4    nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...       1305
# ..                                                 ...        ...
# 121  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...       2703
# 122  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...       2206
# 123  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...       7366
# 124  nyt://article/334d25c3-2380-5065-87cb-68a8472e...       3579
# 125  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...        220
#
#                                                    uri  print_page  \
# 0    nyt://article/81f3db41-e085-5080-8440-aa52b0c2...         NaN
# 1    nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...         NaN
# 2    nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...          10
# 3    nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...          12
# 4    nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...           5
# ..                                                 ...         ...
# 121  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...         NaN
# 122  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...           6
# 123  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...           1
# 124  nyt://article/334d25c3-2380-5065-87cb-68a8472e...         NaN
# 125  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...          26
#
#     print_section                                               text sentiment
# 0             NaN  A FARC leader who helped negotiate a peace acc... -0.261667
# 1             NaN  Achieving lasting peace requires the removal o... -0.329167
# 2               A  Right-wing parties gained strength but did not... -0.071759
# 3               A  The itinerary will include Peru, where Preside... -0.132143
# 4               A  Fleeing crime and economic crisis, more than h... -0.048958
# ..            ...                                                ...       ...
# 121           NaN  After a stunning upset in the American preside... -0.033586
# 122            TR  Though she only got to see part of Chile’s Rou... -0.075000
# 123             A  After decades of atrocities, the warlords were... -0.145833
# 124           NaN  Alfred Nobel’s will set up a prize for the pur... -0.287500
# 125             A  A Notre Dame professor discusses the Peace Acc... -0.375000
#
# [126 rows x 22 columns]

# %%
# plots the individual articles by data point number
# first sorts them in order of time, but does not display dates for visualization purposes (too many dates)
def bar_chart_points(data):
    data = data.sort_values(by='pub_date')
    fig, ax = plt.subplots()
    x = range(len(data['sentiment']))
    for i, val in enumerate(data['sentiment']):
        color = 'red' if val < 0 else 'green'
        ax.bar(i, val, color=color)
    plt.xlabel('Data Points')
    plt.ylabel('Sentiment')
    plt.show()

# %%
# plot_bar_chart_points function test
bar_chart_points(df)

# %%
# average monthly sentiment function
# plots articles by average sentiment-month
def bar_chart_monthly(data):
    data = data.sort_values(by='pub_date')
    data['pub_date'] = pd.to_datetime(data['pub_date'])
    data['month'] = data['pub_date'].dt.strftime('%Y-%m')
    grouped = data.groupby('month').mean()
    fig, ax = plt.subplots()
    x = range(len(grouped.index))
    for i, val in enumerate(grouped['sentiment']):
        color = 'red' if val < 0 else 'green'
        ax.bar(x[i], val, color=color)
    plt.xticks(x, grouped.index, rotation=90)
    plt.xlabel('Month')
    plt.ylabel('Sentiment')
    plt.show()

# %%
bar_chart_monthly(df)

# %% [markdown]
# #function to get the raw data for sentiment
# def group_by_month(data):
#     data['pub_date'] = pd.to_datetime(data['pub_date'])
#     data['month'] = data['pub_date'].dt.strftime('%Y-%m')
#     grouped = data.groupby('month').mean()
#     return grouped
#
# grouped_data = group_by_month(df)
# print(grouped_data)

# %%
# which articles are positive?

# Extract rows where sentiment is greater than or equal to 0
positive_sentiment_rows = df[df['sentiment'] >= 0]

# Print the resulting dataframe
positive_sentiment_rows
# Out:
#                                               abstract  \
# 13   With its award to President Juan Manuel Santos...
# 24   A landmark agreement between the government an...
# 48   The group that won didn’t eliminate any weapon...
# 53   The election puts the unpopular administration...
# 79   Did you stay on top of the most important stor...
# 86   Top Colombian riders, triumphing on the world ...
# 109  The professors were recognized for their effor...
# 117  Old-school merengue is still going strong at E...
#
#                                                web_url  \
# 13   https://www.nytimes.com/2016/10/09/opinion/the...
# 24   https://www.nytimes.com/2016/08/26/opinion/col...
# 48   https://www.nytimes.com/2017/10/09/opinion/nob...
# 53   https://www.nytimes.com/2018/02/07/world/ameri...
# 79   https://www.nytimes.com/interactive/2017/08/06...
# 86   https://www.nytimes.com/2017/06/07/sports/cycl...
# 109  https://www.nytimes.com/2016/10/11/business/no...
# 117  https://www.nytimes.com/interactive/2017/10/06...
#
#                                                snippet  \
# 13   With its award to President Juan Manuel Santos...
# 24   A landmark agreement between the government an...
# 48   The group that won didn’t eliminate any weapon...
# 53   The election puts the unpopular administration...
# 79   Did you stay on top of the most important stor...
# 86   Top Colombian riders, triumphing on the world ...
# 109  The professors were recognized for their effor...
# 117  Old-school merengue is still going strong at E...
#
#                                         lead_paragraph  \
# 13   The history of second-guessing the Nobel Peace...
# 24   The life of every Colombian alive today has be...
# 48   The Norwegian Nobel Committee awarded the Peac...
# 53   BOGOTÁ, Colombia — The Venezuelan government s...
# 79   Did you stay on top of the most important stor...
# 86   BOGOTÁ, Colombia — In a sport long dominated b...
# 109  Oliver Hart and Bengt Holmstrom were awarded t...
# 117  Old-school merengue is still going strong at E...
#
#                            source  \
# 13             The New York Times
# 24             The New York Times
# 48   International New York Times
# 53             The New York Times
# 79             The New York Times
# 86             The New York Times
# 109            The New York Times
# 117            The New York Times
#
#                                             multimedia  \
# 13   [{'rank': 0, 'subtype': 'square320', 'caption'...
# 24   [{'rank': 0, 'subtype': 'sfSpan', 'caption': N...
# 48   [{'rank': 0, 'subtype': 'facebookJumbo', 'capt...
# 53   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 79   [{'rank': 0, 'subtype': 'videoFifteenBySeven13...
# 86   [{'rank': 0, 'subtype': 'videoSmall', 'caption...
# 109                                                 []
# 117  [{'rank': 0, 'subtype': 'hpLarge', 'caption': ...
#
#                                               headline  \
# 13   {'main': 'The Nobel ‘Give Peace a Chance’ Priz...
# 24   {'main': 'Colombia’s Remarkable Peace Process'...
# 48   {'main': 'A Peace Prize That Honors the Quest'...
# 53   {'main': 'Few Challengers in Sight, Venezuela ...
# 79   {'main': 'Global News Quiz: Trump on the Telep...
# 86   {'main': 'Cyclists Chase Glory for Colombia, a...
# 109  {'main': 'Oliver Hart and Bengt Holmstrom Win ...
# 117  {'main': 'The Dominican Dance Party That Refus...
#
#                                               keywords   pub_date  \
# 13   [{'name': 'subject', 'value': 'Nobel Prizes', ... 2016-10-08
# 24   [{'name': 'glocations', 'value': 'Colombia', '... 2016-08-25
# 48   [{'name': 'organizations', 'value': 'Internati... 2017-10-09
# 53   [{'name': 'subject', 'value': 'Elections', 'ra... 2018-02-08
# 79   [{'name': 'glocations', 'value': 'Venezuela', ... 2017-08-06
# 86   [{'name': 'subject', 'value': 'Doping (Sports)... 2017-06-08
# 109  [{'name': 'persons', 'value': 'Appelbaum, Biny... 2016-10-10
# 117  [{'name': 'subject', 'value': 'Bars and Nightc... 2017-10-06
#
#     document_type  ...     type_of_material  \
# 13        article  ...            Editorial
# 24        article  ...            Editorial
# 48        article  ...            Editorial
# 53        article  ...                 News
# 79     multimedia  ...  Interactive Feature
# 86        article  ...                 News
# 109       article  ...                 News
# 117    multimedia  ...  Interactive Feature
#
#                                                    _id word_count  \
# 13   nyt://article/9dea434e-ee5f-55c4-a7a3-d038c850...        428
# 24   nyt://article/63eb10ec-192b-5824-a5ef-7f16cdc6...        600
# 48   nyt://article/d4c67a9a-0f62-5574-bc22-a754d0f6...        449
# 53   nyt://article/c3b21722-c45a-5ee6-8d87-fb3a8220...        520
# 79   nyt://interactive/d0fb26f0-8791-5002-9c40-3436...          0
# 86   nyt://article/766546a3-5648-5538-991b-c4fe1a73...       1242
# 109  nyt://article/3a409af7-a3e1-579a-8cc7-9402528b...       1302
# 117  nyt://interactive/b7ebc0e3-e0d4-5695-9879-55fe...          0
#
#                                                    uri print_page  \
# 13   nyt://article/9dea434e-ee5f-55c4-a7a3-d038c850...         10
# 24   nyt://article/63eb10ec-192b-5824-a5ef-7f16cdc6...         18
# 48   nyt://article/d4c67a9a-0f62-5574-bc22-a754d0f6...        NaN
# 53   nyt://article/c3b21722-c45a-5ee6-8d87-fb3a8220...          9
# 79   nyt://interactive/d0fb26f0-8791-5002-9c40-3436...        NaN
# 86   nyt://article/766546a3-5648-5538-991b-c4fe1a73...         10
# 109  nyt://article/3a409af7-a3e1-579a-8cc7-9402528b...          3
# 117  nyt://interactive/b7ebc0e3-e0d4-5695-9879-55fe...        NaN
#
#     print_section                                               text  \
# 13             SR  With its award to President Juan Manuel Santos...
# 24              A  A landmark agreement between the government an...
# 48            NaN  The group that won didn’t eliminate any weapon...
# 53              A  The election puts the unpopular administration...
# 79            NaN  Did you stay on top of the most important stor...
# 86              B  Top Colombian riders, triumphing on the world ...
# 109             A  The professors were recognized for their effor...
# 117           NaN  Old-school merengue is still going strong at E...
#
#     sentiment    month sentiment_polarity
# 13   0.175000  2016-10                0.0
# 24   0.045000  2016-08                0.0
# 48   0.008929  2017-10                0.0
# 53   0.117857  2018-02                0.0
# 79   0.142157  2017-08                0.0
# 86   0.051420  2017-06                0.0
# 109  0.005000  2016-10                0.0
# 117  0.123485  2017-10                0.0
#
# [8 rows x 24 columns]

# %%
# which articles are negative?

# Extract rows where sentiment is greater than or equal to 0
positive_sentiment_rows = df[df['sentiment'] <= 0]

# Print the resulting dataframe
positive_sentiment_rows
# Out:
#                                               abstract  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2018/04/10/world/ameri...
# 1    https://www.nytimes.com/2018/04/05/opinion/col...
# 2    https://www.nytimes.com/2018/03/12/world/ameri...
# 3    https://www.nytimes.com/2018/03/10/us/politics...
# 4    https://www.nytimes.com/2018/02/17/world/ameri...
# ..                                                 ...
# 121  https://www.nytimes.com/2016/11/09/world/europ...
# 122  https://www.nytimes.com/2018/05/08/travel/chil...
# 123  https://www.nytimes.com/2016/09/11/world/ameri...
# 124  https://www.nytimes.com/2017/10/06/world/nobel...
# 125  https://www.nytimes.com/2016/11/25/opinion/col...
#
#                                                snippet  \
# 0    A FARC leader who helped negotiate a peace acc...
# 1    Achieving lasting peace requires the removal o...
# 2    Right-wing parties gained strength but did not...
# 3    The itinerary will include Peru, where Preside...
# 4    Fleeing crime and economic crisis, more than h...
# ..                                                 ...
# 121  After a stunning upset in the American preside...
# 122  Though she only got to see part of Chile’s Rou...
# 123  After decades of atrocities, the warlords were...
# 124  Alfred Nobel’s will set up a prize for the pur...
# 125  A Notre Dame professor discusses the Peace Acc...
#
#                                         lead_paragraph  \
# 0    MEDELLÍN, Colombia — A former guerrilla peace ...
# 1    Washington — A nation’s transition from confli...
# 2    MEDELLÍN, Colombia — Colombians elected a divi...
# 3    President Trump will make the first visit of h...
# 4    CÚCUTA, Colombia — For the past three weeks, W...
# ..                                                 ...
# 121  The election of Donald J. Trump as president o...
# 122  Our columnist, Jada Yuan, is visiting each des...
# 123  CALABAZO, Colombia — Skinny but imposing with ...
# 124  “For their efforts to end the use of sexual vi...
# 125                                     To the Editor:
#
#                            source  \
# 0              The New York Times
# 1    International New York Times
# 2              The New York Times
# 3              The New York Times
# 4              The New York Times
# ..                            ...
# 121            The New York Times
# 122            The New York Times
# 123            The New York Times
# 124            The New York Times
# 125            The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 121                                                 []
# 122  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 123  [{'rank': 0, 'subtype': 'square320', 'caption'...
# 124  [{'rank': 0, 'subtype': 'hpLarge', 'caption': ...
# 125                                                 []
#
#                                               headline  \
# 0    {'main': 'Former Colombian Rebel Commander Is ...
# 1    {'main': 'Colombia’s Imperiled Transition', 'k...
# 2    {'main': 'Colombian Election Brings Divided Co...
# 3    {'main': 'Trump to Make First Visit as Preside...
# 4    {'main': 'In Colombia Border Town, Desperate V...
# ..                                                 ...
# 121  {'main': 'Across the World, Shock and Uncertai...
# 122  {'main': 'The 52 Places Traveler: In Chile, a ...
# 123  {'main': 'The Secret History of Colombia’s Par...
# 124  {'main': 'Nobel Peace Prize Winners Throughout...
# 125  {'main': 'Colombia’s Peace Agreement', 'kicker...
#
#                                               keywords   pub_date  \
# 0    [{'name': 'persons', 'value': 'Hernandez, Seus... 2018-04-10
# 1    [{'name': 'organizations', 'value': 'Revolutio... 2018-04-05
# 2    [{'name': 'glocations', 'value': 'Colombia', '... 2018-03-12
# 3    [{'name': 'subject', 'value': 'United States I... 2018-03-10
# 4    [{'name': 'glocations', 'value': 'Colombia', '... 2018-02-17
# ..                                                 ...        ...
# 121  [{'name': 'subject', 'value': 'Presidential El... 2016-11-09
# 122  [{'name': 'glocations', 'value': 'Chile', 'ran... 2018-05-08
# 123  [{'name': 'glocations', 'value': 'Colombia', '... 2016-09-10
# 124  [{'name': 'subject', 'value': 'Nobel Prizes', ... 2017-10-06
# 125  [{'name': 'glocations', 'value': 'Colombia', '... 2016-11-25
#
#     document_type  ... type_of_material  \
# 0         article  ...             News
# 1         article  ...            Op-Ed
# 2         article  ...             News
# 3         article  ...             News
# 4         article  ...             News
# ..            ...  ...              ...
# 121       article  ...             News
# 122       article  ...             News
# 123       article  ...             News
# 124       article  ...             News
# 125       article  ...           Letter
#
#                                                    _id word_count  \
# 0    nyt://article/81f3db41-e085-5080-8440-aa52b0c2...        642
# 1    nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...       1111
# 2    nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...        519
# 3    nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...        467
# 4    nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...       1305
# ..                                                 ...        ...
# 121  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...       2703
# 122  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...       2206
# 123  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...       7366
# 124  nyt://article/334d25c3-2380-5065-87cb-68a8472e...       3579
# 125  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...        220
#
#                                                    uri print_page  \
# 0    nyt://article/81f3db41-e085-5080-8440-aa52b0c2...        NaN
# 1    nyt://article/f04d5cbe-2c52-5cc7-8567-85535988...        NaN
# 2    nyt://article/2d6e17b5-9025-5541-90e7-53caefc8...         10
# 3    nyt://article/88ecbfbd-7bd9-58ca-83b8-00239d99...         12
# 4    nyt://article/226c8f9f-9be5-53ba-89a4-fb0fd83b...          5
# ..                                                 ...        ...
# 121  nyt://article/e0a5a53b-4cb2-5a6e-abee-a7aa85be...        NaN
# 122  nyt://article/2c70ed6e-a5dd-5888-9d16-383f179c...          6
# 123  nyt://article/5da5d589-f4fe-5c2a-ace6-b57a248e...          1
# 124  nyt://article/334d25c3-2380-5065-87cb-68a8472e...        NaN
# 125  nyt://article/181b1b73-4344-5cd7-9796-3a133a8d...         26
#
#     print_section                                               text  \
# 0             NaN  A FARC leader who helped negotiate a peace acc...
# 1             NaN  Achieving lasting peace requires the removal o...
# 2               A  Right-wing parties gained strength but did not...
# 3               A  The itinerary will include Peru, where Preside...
# 4               A  Fleeing crime and economic crisis, more than h...
# ..            ...                                                ...
# 121           NaN  After a stunning upset in the American preside...
# 122            TR  Though she only got to see part of Chile’s Rou...
# 123             A  After decades of atrocities, the warlords were...
# 124           NaN  Alfred Nobel’s will set up a prize for the pur...
# 125             A  A Notre Dame professor discusses the Peace Acc...
#
#     sentiment    month sentiment_polarity
# 0   -0.261667  2018-04                0.0
# 1   -0.329167  2018-04                0.0
# 2   -0.071759  2018-03                0.0
# 3   -0.132143  2018-03                0.0
# 4   -0.048958  2018-02                0.0
# ..        ...      ...                ...
# 121 -0.033586  2016-11                0.0
# 122 -0.075000  2018-05                0.0
# 123 -0.145833  2016-09                0.0
# 124 -0.287500  2017-10                0.0
# 125 -0.375000  2016-11                0.0
#
# [118 rows x 24 columns]

# %% [markdown]
# #TESTING SPACY -- BETTER FOR ARTICLES
# nlp = spacy.load("en_core_web_sm")
# doc = nlp(sentences[0])
# print(doc.text)
# for token in doc:
#     print(token.text, token.pos_, token.dep_)

# %% [markdown]
# #word type classification using spacy
# import spacy
# nlp = spacy.load("en_core_web_sm")
# nlp = en_core_web_sm.load()
# doc = nlp("This is a sentence.")
# print([(w.text, w.pos_) for w in doc])

# %% [markdown]
# #sentiment analysis using spacy
# #NOT WORKING -- ALL SENTIMENT IS SHOWN AS ZERO. NEED TO FIX
# #Load the spaCy model
# nlp = spacy.load("en_core_web_sm")
#
# #Combine the three columns into one
# df["text"] = df["abstract"].astype(str) + df["lead_paragraph"].astype(str) + df["byline"].astype(str)
#
# #Create a new column for the sentiment scores
# df["sentiment"] = df["text"].apply(lambda x: nlp(x).sentiment)
#
# #Format the pub_date column as a date
# df["pub_date"] = pd.to_datetime(df["pub_date"])
#
# #Plot the sentiment scores over time
# sns.lineplot(x="pub_date", y="sentiment", data=df)
