# %%
from textblob import TextBlob
import requests, math, time
import csv, pathlib
import pandas as pd
import os
import openai
import json
import seaborn as sns
import json
import sys
import warnings
import spacy

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
print("This program uses an ML natural language model (GPT-3) to summarize and analyze articles in the NYT\nto summarize and do sentiment analysis on a given subject, person, or location (or any other keyword) over time")
print("\nYou can input your query using natural language like this: \nSearch all articles about Michael Jackson from 1990 to his death")
print("\nSearch all articles about Enron since its IPO up to its collapse")

print("\nNote: If you want detailed and accurate answers, it is better to include the dates in the query.")
# Out:
# This program uses an ML natural language model (GPT-3) to summarize and analyze articles in the NYT
# to summarize and do sentiment analysis on a given subject, person, or location (or any other keyword) over time
#
# You can input your query using natural language like this:
# Search all articles about Michael Jackson from 1990 to his death
#
# Search all articles about Enron since its IPO up to its collapse
#
# Note: If you want detailed and accurate answers, it is better to include the dates in the query.

# %%
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"

# %%
# Open the JSON file in read mode (OpenAI)
with open("..//api_key.json", "r") as f:
    # Load the JSON data from the file
    data = json.load(f)
    # Get the API key from the JSON data
    api_key = data["api_key"]

# Set the API key
openai.api_key = api_key

# %%
#Open the JSON files in read mode (NYT API Key)
with open("..//nyt_key.json", "r") as f:
    # Load the JSON data from the file
    data = json.load(f)
    # Get the API key from the JSON data
    api_key = data["api_key"]

# Set the API key
nyt_key = api_key

# %%
query = str(input("Enter the search query: "))
# Out:
# Enter the search query: Search all articles about Steve Ballmer since he launched Windows Phone to his departure from Microsoft

# %%
#turning the response from natural language to objects that are readable by the NYT API
response_keyword = openai.Completion.create(
  model="text-davinci-003",
  prompt="Find the main keyword (a name, a location, etc) from this query and nothing else: " + query,
  temperature=0.7,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

keyword = response_keyword.choices[0].text

def remove_leading_trailing_spaces(obj):
    # Use the strip() method to remove leading and trailing spaces
    return obj.strip()

keyword = remove_leading_trailing_spaces(keyword)

response_date = openai.Completion.create(
  model="text-davinci-003",
  prompt="In number format, and adding no extra text tell me the year, month, day (YYYYMMDD) relevant to this query (there should be two dates, beggining and end separated by a single comma). If no indication of time in query, output NA. Years start on 0101 and end 1231. If no end date, add today's date: " + query,
  temperature=0.5,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

dates = response_date.choices[0].text

# Split the input string into a list of dates
dates = dates.split(",")

# Assign the first date to begin_date
begin_date = dates[0]

# Assign the second date to end_date
end_date = dates[1]

# We need to remove all spaces and non-numeric characters
begin_date = ''.join([c for c in begin_date if c.isdigit()])
end_date = ''.join([c for c in end_date if c.isdigit()])

# %%
# Adding + signs for entries with multiple words
def format_keyword(keyword):
    # Split the keyword into a list of words
    words = keyword.split()
    
    # Join the words with a + separator
    formatted_keyword = "+".join(words)
    
    return formatted_keyword

keyword = format_keyword(keyword)

# %%
#checking out outputs
print(keyword)
print(begin_date)
print(end_date)
# Out:
# Steve+Ballmer
# 20101203
# 20141014

# %%
# GETTING THE NUMBER OF HITS FIRST (WE DO NOT WANT TO EXCEED API CALL LIMIT TOO QUICKLY)
def get_num_hits(api_key, keyword, begin_date, end_date):
    # Set up the parameters for the API request
    base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={keyword}'

    params = {
        'api-key': api_key,
        'q': keyword,
        'page': 0,
        'begin_date': begin_date,
        'end_date': end_date
    }
    response = requests.get(base_url, params=params)
    data = response.json()

    # Retrieve the number of hits
    num_hits = data['response']['meta']['hits']

    return num_hits

# %%
get_num_hits(nyt_key, keyword, begin_date, end_date)
# Out:
# 152

# %%
# TESTING VERSION WITH ERROR HANDLING
def search_articles(api_key, keyword, begin_date, end_date):
    # Set up the parameters for the API request
    base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={keyword}'

    # Create an empty dataframe to store the results
    df = pd.DataFrame()

    # Set the number of articles to retrieve
    num_articles = 0

    # Perform the API request for each page
    page = 0
    while True:
        params = {
            'api-key': api_key,
            'q': keyword,
            'page': page,
            'begin_date': begin_date,
            'end_date': end_date
        }
        response = requests.get(base_url, params=params)
        if response.status_code != 200:
            raise Exception(f'Request failed with status code {response.status_code}')
        data = response.json()

        # Check if the response has the expected format
        if 'response' not in data or 'docs' not in data['response']:
            raise Exception(f'Unexpected response format: {data}')

        # Add the articles to the dataframe
        for article in data['response']['docs']:
            df = df.append(article, ignore_index=True)
            num_articles += 1

        # Check if there are more articles available
        if len(data['response']['docs']) == 0:
            break

        # Add a delay to avoid exceeding the API rate limit
        # The limit for the NYT API per docs is 6 seconds per request, 10 per minute
        #(https://developer.nytimes.com/faq#:~:text=Yes%2C%20there%20are%20two%20rate%20limits%20per%20API%3A,higher%20rate%20limit%2C%20please%20contact%20us%20at%20code%40nytimes.com.)
        time.sleep(6)
        page += 1
    
    return df

# %%
# Testing comprehensive search
df = search_articles(nyt_key, keyword, begin_date, end_date)

# %%
df
# Out:
#                                               abstract  \
# 0    Apple and Microsoft have posted poor stock per...
# 1          The barbarians always take over in the end.
# 2    Los Angeles Clippers owner and former Microsof...
# 3    The tech company’s former chief executive said...
# 4    The tech company’s former chief executive said...
# ..                                                 ...
# 147  Prosecutors’ winning streak in insider trading...
# 148  Wall Street’s biggest banks cash in on so-call...
# 149  The sweet, innocent ideas and ruthless power p...
# 150  The wildly popular Kinect bred a rich subcultu...
# 151         Readers sound off on the latest headlines.
#
#                                                web_url  \
# 0    https://bits.blogs.nytimes.com/2013/04/23/why-...
# 1    https://krugman.blogs.nytimes.com/2013/08/24/s...
# 2    https://www.nytimes.com/video/multimedia/10000...
# 3    https://bits.blogs.nytimes.com/2014/08/20/dail...
# 4    https://www.nytimes.com/2014/08/20/technology/...
# ..                                                 ...
# 147  https://dealbook.nytimes.com/2014/07/09/mornin...
# 148  https://dealbook.nytimes.com/2014/07/29/mornin...
# 149  https://www.nytimes.com/2013/10/13/magazine/al...
# 150  https://www.nytimes.com/2012/06/03/magazine/ho...
# 151  https://www.nytimes.com/2014/06/08/sports/lett...
#
#                                                snippet  \
# 0    Apple and Microsoft have posted poor stock per...
# 1          The barbarians always take over in the end.
# 2    Los Angeles Clippers owner and former Microsof...
# 3    The tech company’s former chief executive said...
# 4    The tech company’s former chief executive said...
# ..                                                 ...
# 147  Prosecutors’ winning streak in insider trading...
# 148  Wall Street’s biggest banks cash in on so-call...
# 149  The sweet, innocent ideas and ruthless power p...
# 150  The wildly popular Kinect bred a rich subcultu...
# 151         Readers sound off on the latest headlines.
#
#                                         lead_paragraph print_section  \
# 0    On Monday, Matthew Panzarino of the Next Web, ...             B
# 1    Microsoft is still a very profitable company; ...           NaN
# 2    Los Angeles Clippers owner and former Microsof...           NaN
# 3    Steven A. Ballmer’s era at Microsoft has come ...           NaN
# 4    SEATTLE — Steven A. Ballmer’s era at Microsoft...             B
# ..                                                 ...           ...
# 147  Since the government’s crackdown on insider tr...           NaN
# 148  The chief executives at JPMorgan Chase and Gol...           NaN
# 149  Right in the center of South Park, a large, gr...            MM
# 150  When the Kinect was introduced in November 201...            MM
# 151                              To the Sports Editor:            SP
#
#     print_page              source  \
# 0            7  The New York Times
# 1          NaN  The New York Times
# 2          NaN             Reuters
# 3          NaN  The New York Times
# 4            2  The New York Times
# ..         ...                 ...
# 147        NaN  The New York Times
# 148        NaN  The New York Times
# 149         22  The New York Times
# 150         58  The New York Times
# 151          4  The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 1                                                   []
# 2    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 3    [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 4    [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# ..                                                 ...
# 147                                                 []
# 148                                                 []
# 149  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 150  [{'rank': 0, 'subtype': 'jumbo', 'caption': No...
# 151                                                 []
#
#                                               headline  \
# 0    {'main': 'Why Tim Cook Is Like Steve Ballmer',...
# 1    {'main': 'Steve Ballmer, Meet Ibn Khaldun', 'k...
# 2    {'main': 'At L.A. Clippers, Steve Ballmer priz...
# 3    {'main': 'Daily Report: Steve Ballmer Resigns ...
# 4    {'main': 'Steve Ballmer Quits Microsoft Board,...
# ..                                                 ...
# 147  {'main': 'Morning Agenda: Prosecutors’ Perfect...
# 148  {'main': 'Morning Agenda: Banks Reap Rewards o...
# 149  {'main': 'All Is Fair in Love and Twitter', 'k...
# 150  {'main': 'Freaks, Geeks and Microsoft', 'kicke...
# 151  {'main': 'Letters to the Sports Editor', 'kick...
#
#                                               keywords  \
# 0    [{'name': 'persons', 'value': 'Ballmer, Steven...
# 1                                                   []
# 2                                                   []
# 3    [{'name': 'subject', 'value': 'Appointments an...
# 4    [{'name': 'persons', 'value': 'Ballmer, Steven...
# ..                                                 ...
# 147                                                 []
# 148                                                 []
# 149  [{'name': 'persons', 'value': 'Dorsey, Jack', ...
# 150  [{'name': 'subject', 'value': 'Software', 'ran...
# 151  [{'name': 'subject', 'value': 'Baseball', 'ran...
#
#                      pub_date document_type news_desk       section_name  \
# 0    2013-04-23T10:00:48+0000       article                   Technology
# 1    2013-08-24T17:27:08+0000       article                      Opinion
# 2    2014-09-25T02:43:49+0000    multimedia            Multimedia/Photos
# 3    2014-08-20T10:25:26+0000       article  Business         Technology
# 4    2014-08-19T19:13:13+0000       article  Business         Technology
# ..                        ...           ...       ...                ...
# 147  2014-07-09T11:45:42+0000       article  Business       Business Day
# 148  2014-07-29T11:57:04+0000       article  Business       Business Day
# 149  2013-10-09T09:00:11+0000       article  Magazine           Magazine
# 150  2012-05-31T11:00:02+0000       article  Magazine           Magazine
# 151  2014-06-07T15:04:54+0000       article    Sports             Sports
#
#                                                 byline type_of_material  \
# 0    {'original': 'By Nick Wingfield', 'person': [{...             News
# 1    {'original': 'By Paul Krugman', 'person': [{'f...             News
# 2    {'original': None, 'person': [], 'organization...            Video
# 3    {'original': 'By The New York Times', 'person'...             News
# 4    {'original': 'By Nick Wingfield', 'person': [{...             News
# ..                                                 ...              ...
# 147  {'original': 'By Sydney Ember', 'person': [{'f...             News
# 148  {'original': 'By Sydney Ember', 'person': [{'f...             News
# 149  {'original': 'By Nick Bilton', 'person': [{'fi...             News
# 150  {'original': 'By Rob Walker', 'person': [{'fir...             News
# 151  {'original': None, 'person': [], 'organization...           Letter
#
#                                                    _id  word_count  \
# 0    nyt://article/c19c6080-aa44-53f6-abe5-1a403b96...         509
# 1    nyt://article/e35162fe-5e2f-58e0-a724-be82c38e...         444
# 2     nyt://video/2ad2ff3c-3788-5667-8d55-478717398a42           0
# 3    nyt://article/f3ee4ceb-e6c7-5005-a7fc-1aea0e0e...         176
# 4    nyt://article/83cade80-171d-53d5-973f-b2c7ce2c...         652
# ..                                                 ...         ...
# 147  nyt://article/3bd02029-fa62-5bdc-83b7-38bd2c99...        2047
# 148  nyt://article/9e7c8654-69f8-571e-872b-90feed98...        2022
# 149  nyt://article/a9ecab19-44b9-57b5-9e2c-19484c18...        6149
# 150  nyt://article/c2ebfa22-e8da-5d79-8c14-d5d6e5b3...        2858
# 151  nyt://article/017fabc0-5d35-53d5-8577-1242783e...         744
#
#                                                    uri subsection_name
# 0    nyt://article/c19c6080-aa44-53f6-abe5-1a403b96...             NaN
# 1    nyt://article/e35162fe-5e2f-58e0-a724-be82c38e...             NaN
# 2     nyt://video/2ad2ff3c-3788-5667-8d55-478717398a42             NaN
# 3    nyt://article/f3ee4ceb-e6c7-5005-a7fc-1aea0e0e...             NaN
# 4    nyt://article/83cade80-171d-53d5-973f-b2c7ce2c...             NaN
# ..                                                 ...             ...
# 147  nyt://article/3bd02029-fa62-5bdc-83b7-38bd2c99...             NaN
# 148  nyt://article/9e7c8654-69f8-571e-872b-90feed98...             NaN
# 149  nyt://article/a9ecab19-44b9-57b5-9e2c-19484c18...             NaN
# 150  nyt://article/c2ebfa22-e8da-5d79-8c14-d5d6e5b3...             NaN
# 151  nyt://article/017fabc0-5d35-53d5-8577-1242783e...             NaN
#
# [152 rows x 20 columns]

# %%
# NO NEED TO RUN THIS
# Version of NYT article search that returns the first 100 articles (faster but not comprehensive)
def search_articles(api_key, keyword, begin_date, end_date):
    # Set up the parameters for the API request
    base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={keyword}'

    # Create an empty dataframe to store the results
    df = pd.DataFrame()

    # Set the number of pages to retrieve
    num_pages = 10

    # Perform the API request for each page
    for page in range(num_pages):
        params = {
            'api-key': nyt_key,
            'q': keyword,
            'page': page,
            'begin_date': begin_date,
            'end_date': end_date
        }
        response = requests.get(base_url, params=params)
        data = response.json()

        # Add the articles to the dataframe
        for article in data['response']['docs']:
            df = df.append(article, ignore_index=True)
    
    return df

# %%
#Testing limited search
df = search_articles(nyt_key, keyword, begin_date, end_date)

# %%
base_url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={keyword}'

if begin_date:
    base_url += f'&begin_date={begin_date}'
if end_date:
    base_url += f'&end_date={end_date}'
    
    
base_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Microsoft+Surface&begin_date=20130902&end_date=20140214'

# %%
df
# Out:
#                                              abstract  \
# 0   Apple and Microsoft have posted poor stock per...
# 1         The barbarians always take over in the end.
# 2   Los Angeles Clippers owner and former Microsof...
# 3   The tech company’s former chief executive said...
# 4   The tech company’s former chief executive said...
# ..                                                ...
# 95  Bruce Levenson, who said Sunday he would sell ...
# 96  Although there was no confirmation of the numb...
# 97  Microsoft and Nokia have yet to prove whether ...
# 98  Delivery start-ups are back. Here are five met...
# 99    Corrections appearing in print on June 6, 2014.
#
#                                               web_url  \
# 0   https://bits.blogs.nytimes.com/2013/04/23/why-...
# 1   https://krugman.blogs.nytimes.com/2013/08/24/s...
# 2   https://www.nytimes.com/video/multimedia/10000...
# 3   https://bits.blogs.nytimes.com/2014/08/20/dail...
# 4   https://www.nytimes.com/2014/08/20/technology/...
# ..                                                ...
# 95  https://www.nytimes.com/2014/09/09/sports/bask...
# 96  https://www.nytimes.com/2014/05/29/sports/bask...
# 97  https://bits.blogs.nytimes.com/2011/11/22/noki...
# 98  https://boss.blogs.nytimes.com/2014/08/19/toda...
# 99  https://www.nytimes.com/2014/06/06/pageoneplus...
#
#                                               snippet  \
# 0   Apple and Microsoft have posted poor stock per...
# 1         The barbarians always take over in the end.
# 2   Los Angeles Clippers owner and former Microsof...
# 3   The tech company’s former chief executive said...
# 4   The tech company’s former chief executive said...
# ..                                                ...
# 95  Bruce Levenson, who said Sunday he would sell ...
# 96  Although there was no confirmation of the numb...
# 97  Microsoft and Nokia have yet to prove whether ...
# 98  Delivery start-ups are back. Here are five met...
# 99    Corrections appearing in print on June 6, 2014.
#
#                                        lead_paragraph print_section  \
# 0   On Monday, Matthew Panzarino of the Next Web, ...             B
# 1   Microsoft is still a very profitable company; ...           NaN
# 2   Los Angeles Clippers owner and former Microsof...           NaN
# 3   Steven A. Ballmer’s era at Microsoft has come ...           NaN
# 4   SEATTLE — Steven A. Ballmer’s era at Microsoft...             B
# ..                                                ...           ...
# 95  In the late 1970s, frustrated with his job edi...             B
# 96  The potentially frothy bidding to purchase the...             B
# 97   Microsoft and Nokia have yet to prove whether...           NaN
# 98  What’s affecting me, my clients and other smal...           NaN
# 99                                         FRONT PAGE             A
#
#    print_page              source  \
# 0           7  The New York Times
# 1         NaN  The New York Times
# 2         NaN             Reuters
# 3         NaN  The New York Times
# 4           2  The New York Times
# ..        ...                 ...
# 95         19  The New York Times
# 96         12  The New York Times
# 97        NaN  The New York Times
# 98        NaN  The New York Times
# 99          2  The New York Times
#
#                                            multimedia  \
# 0   [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 1                                                  []
# 2   [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 3   [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 4   [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# ..                                                ...
# 95  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 96  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 97  [{'rank': 0, 'subtype': 'blog480', 'caption': ...
# 98                                                 []
# 99                                                 []
#
#                                              headline  \
# 0   {'main': 'Why Tim Cook Is Like Steve Ballmer',...
# 1   {'main': 'Steve Ballmer, Meet Ibn Khaldun', 'k...
# 2   {'main': 'At L.A. Clippers, Steve Ballmer priz...
# 3   {'main': 'Daily Report: Steve Ballmer Resigns ...
# 4   {'main': 'Steve Ballmer Quits Microsoft Board,...
# ..                                                ...
# 95  {'main': 'Hawks Owner Had His Struggles With T...
# 96  {'main': 'Clippers Draw Some High-Profile Offe...
# 97  {'main': 'Nokia’s Microsoft Phones May Not Get...
# 98  {'main': 'Today in Small Business: Write a Let...
# 99  {'main': 'Corrections: June 6, 2014', 'kicker'...
#
#                                              keywords  \
# 0   [{'name': 'persons', 'value': 'Ballmer, Steven...
# 1                                                  []
# 2                                                  []
# 3   [{'name': 'subject', 'value': 'Appointments an...
# 4   [{'name': 'persons', 'value': 'Ballmer, Steven...
# ..                                                ...
# 95  [{'name': 'subject', 'value': 'Basketball', 'r...
# 96  [{'name': 'subject', 'value': 'Basketball', 'r...
# 97  [{'name': 'subject', 'value': 'Cellular Teleph...
# 98  [{'name': 'subject', 'value': 'Small Business'...
# 99                                                 []
#
#                     pub_date document_type news_desk       section_name  \
# 0   2013-04-23T10:00:48+0000       article                   Technology
# 1   2013-08-24T17:27:08+0000       article                      Opinion
# 2   2014-09-25T02:43:49+0000    multimedia            Multimedia/Photos
# 3   2014-08-20T10:25:26+0000       article  Business         Technology
# 4   2014-08-19T19:13:13+0000       article  Business         Technology
# ..                       ...           ...       ...                ...
# 95  2014-09-09T01:20:29+0000       article    Sports             Sports
# 96  2014-05-28T16:09:15+0000       article    Sports             Sports
# 97  2011-11-22T23:39:37+0000       article                   Technology
# 98  2014-08-19T16:26:15+0000       article  Business       Business Day
# 99  2014-06-06T05:52:35+0000       article   Summary        Corrections
#
#                                                byline type_of_material  \
# 0   {'original': 'By Nick Wingfield', 'person': [{...             News
# 1   {'original': 'By Paul Krugman', 'person': [{'f...             News
# 2   {'original': None, 'person': [], 'organization...            Video
# 3   {'original': 'By The New York Times', 'person'...             News
# 4   {'original': 'By Nick Wingfield', 'person': [{...             News
# ..                                                ...              ...
# 95  {'original': 'By Billy Witz', 'person': [{'fir...             News
# 96  {'original': 'By Richard Sandomir and Scott Ca...             News
# 97  {'original': 'By Brian X. Chen', 'person': [{'...             News
# 98  {'original': 'By Gene Marks', 'person': [{'fir...             News
# 99  {'original': None, 'person': [], 'organization...             News
#
#                                                   _id  word_count  \
# 0   nyt://article/c19c6080-aa44-53f6-abe5-1a403b96...         509
# 1   nyt://article/e35162fe-5e2f-58e0-a724-be82c38e...         444
# 2    nyt://video/2ad2ff3c-3788-5667-8d55-478717398a42           0
# 3   nyt://article/f3ee4ceb-e6c7-5005-a7fc-1aea0e0e...         176
# 4   nyt://article/83cade80-171d-53d5-973f-b2c7ce2c...         652
# ..                                                ...         ...
# 95  nyt://article/cacd6167-8d18-5e9f-89dc-eab25f01...         998
# 96  nyt://article/f689071a-8105-5707-99c6-f34122c6...        1081
# 97  nyt://article/566bb090-fcc9-5e4f-969b-0e270363...         576
# 98  nyt://article/ae83303f-641f-53ff-b22b-c357bcb6...         521
# 99  nyt://article/9285a130-076d-59ea-80a2-b0373a2e...         686
#
#                                                   uri   subsection_name
# 0   nyt://article/c19c6080-aa44-53f6-abe5-1a403b96...               NaN
# 1   nyt://article/e35162fe-5e2f-58e0-a724-be82c38e...               NaN
# 2    nyt://video/2ad2ff3c-3788-5667-8d55-478717398a42               NaN
# 3   nyt://article/f3ee4ceb-e6c7-5005-a7fc-1aea0e0e...               NaN
# 4   nyt://article/83cade80-171d-53d5-973f-b2c7ce2c...               NaN
# ..                                                ...               ...
# 95  nyt://article/cacd6167-8d18-5e9f-89dc-eab25f01...    Pro Basketball
# 96  nyt://article/f689071a-8105-5707-99c6-f34122c6...    Pro Basketball
# 97  nyt://article/566bb090-fcc9-5e4f-969b-0e270363...               NaN
# 98  nyt://article/ae83303f-641f-53ff-b22b-c357bcb6...  Entrepreneurship
# 99  nyt://article/9285a130-076d-59ea-80a2-b0373a2e...               NaN
#
# [100 rows x 20 columns]

# %%
#Sentiment Analysis and Seaborn code

# Combine the three columns into one
df["text"] = df["abstract"].astype(str) + df["lead_paragraph"].astype(str) + df["byline"].astype(str)


# Create a new column for the sentiment scores
df["sentiment"] = df["text"].apply(lambda x: TextBlob(x).sentiment.polarity)

# Format the pub_date column as a date
df["pub_date"] = pd.to_datetime(df["pub_date"])

# Plot the sentiment scores over time
sns.lineplot(x="pub_date", y="sentiment", data=df)
# Out:
# <AxesSubplot:xlabel='pub_date', ylabel='sentiment'>

# %%
# Corrected plot
sns.lineplot(
    data=df, 
    x="pub_date", y="sentiment",
    height=5, aspect=2 
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 # Corrected plot
# ----> 2 sns.lineplot(
#       3     data=df,
#       4     x="pub_date", y="sentiment",
#       5     height=5, aspect=2
#       6 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:436, in _LinePlotter.plot(self, ax, kws)
#     425 """Draw the plot onto an axes, passing matplotlib kwargs."""
#     427 # Draw a test plot, using the passed in kwargs. The goal here is to
#     428 # honor both (a) the current state of the plot cycler and (b) the
#     429 # specified kwargs on all the lines we will draw, overriding when
#    (...)
#     433 # gotten from the corresponding matplotlib function, and calling the
#     434 # function will advance the axes property cycle.
# --> 436 scout, = ax.plot([], [], **kws)
#     438 orig_color = kws.pop("color", scout.get_color())
#     439 orig_marker = kws.pop("marker", scout.get_marker())
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:538, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:538, in <listcomp>(.0)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:531, in <genexpr>(.0)
#     528 else:
#     529     labels = [label] * n_datasets
# --> 531 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                       {**kwargs, 'label': label})
#     533           for j, label in enumerate(labels))
#     535 if return_kwargs:
#     536     return list(result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py:393, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     389 self.set_markeredgewidth(markeredgewidth)
#     391 # update kwargs before updating data to give the caller a
#     392 # chance to init axes (and hence unit support)
# --> 393 self.update(kwargs)
#     394 self.pickradius = pickradius
#     395 self.ind_offset = 0
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Line2D' object has no property 'height'

# %%
import spacy
from spacy.lang.en.examples import sentences 

nlp = spacy.load("en_core_web_sm")
doc = nlp(sentences[0])
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple is looking at buying U.K. startup for $1 billion
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %%
import spacy
import en_core_web_sm
nlp = spacy.load("en_core_web_sm")
nlp = en_core_web_sm.load()
doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 import spacy
# ----> 2 import en_core_web_sm
#       3 nlp = spacy.load("en_core_web_sm")
#       4 nlp = en_core_web_sm.load()
#
# ModuleNotFoundError: No module named 'en_core_web_sm'

# %%
# sentiment analysis using spacy
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Combine the three columns into one
df["text"] = df["abstract"].astype(str) + df["lead_paragraph"].astype(str) + df["byline"].astype(str)

# Create a new column for the sentiment scores
df["sentiment"] = df["text"].apply(lambda x: nlp(x).sentiment)

# Format the pub_date column as a date
df["pub_date"] = pd.to_datetime(df["pub_date"])

# Plot the sentiment scores over time
sns.lineplot(x="pub_date", y="sentiment", data=df)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/andy/Documents/GitHub/NYT-GPT/NYT Search app V6.ipynb Cell 17 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/andy/Documents/GitHub/NYT-GPT/NYT%20Search%20app%20V6.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> import spacy
#       <a href='vscode-notebook-cell:/Users/andy/Documents/GitHub/NYT-GPT/NYT%20Search%20app%20V6.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> # Load the spaCy model
# ----> <a href='vscode-notebook-cell:/Users/andy/Documents/GitHub/NYT-GPT/NYT%20Search%20app%20V6.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> nlp = spacy.load("en_core_web_sm")
#       <a href='vscode-notebook-cell:/Users/andy/Documents/GitHub/NYT-GPT/NYT%20Search%20app%20V6.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a> # Combine the three columns into one
#       <a href='vscode-notebook-cell:/Users/andy/Documents/GitHub/NYT-GPT/NYT%20Search%20app%20V6.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a> df["text"] = df["abstract"].astype(str) + df["lead_paragraph"].astype(str) + df["byline"].astype(str)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/spacy/__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      37     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      38 ) -> Language:
#      39     """Load a spaCy model from an installed package or a local path.
#      40
#      41     name (str): Package name or model path.
#    (...)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#      57         disable=disable,
#      58         enable=enable,
#      59         exclude=exclude,
#      60         config=config,
#      61     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/spacy/util.py:439, in load_model(name, vocab, disable, enable, exclude, config)
#     437 if name in OLD_MODEL_SHORTCUTS:
#     438     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 439 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
print(df.columns)
# Out:
# Index(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'print_section',
#        'print_page', 'source', 'multimedia', 'headline', 'keywords',
#        'pub_date', 'document_type', 'news_desk', 'section_name',
#        'subsection_name', 'byline', 'type_of_material', '_id', 'word_count',
#        'uri', 'text', 'sentiment'],
#       dtype='object')

# %%
# Convert the pub_date column to datetime
df['pub_date'] = pd.to_datetime(df['pub_date'])

# Extract only the date part of the datetime
df['pub_date'] = pd.DatetimeIndex(df['pub_date']).date

# %%
# Convert the pub_date column to datetime
df['pub_date'] = pd.to_datetime(df['pub_date'])
print(df['pub_date'].dtype)

# Extract only the date part of the datetime
df['pub_date'] = pd.DatetimeIndex(df['pub_date']).date
# Out:
# datetime64[ns]

# %%
# Let's filter dates
# Convert the string to a datetime
date = pd.to_datetime('2016-11-29')

# Select articles with a pub_date on or before January 1, 2020
df_filtered = df.loc[df['pub_date'] <= date]

# %%
df_filtered
# Out:
#                                              abstract  \
# 0   How Steve Jobs used his Apple millions to turn...
# 1   Apple C.E.O. Steve Jobs discusses the new iPho...
# 2   The company announced a new version of the iPh...
# 3   A lot of us carry a little bit of Steve Jobs a...
# 4   Buoyed by unusually strong Macintosh sales, th...
# ..                                                ...
# 95  Though it has been widely reported that Bear S...
# 96  AT&T, the exclusive carrier for the iPhone sai...
# 97  EVERETT, Washington — Step aside, Steve Jobs. ...
# 98  SAN FRANCISCO — The chief executive of Apple, ...
# 99  The Universal Music Group notified Apple that ...
#
#                                               web_url  \
# 0   https://www.nytimes.com/2008/06/22/books/revie...
# 1   https://www.nytimes.com/video/technology/11948...
# 2   https://www.nytimes.com/2008/06/10/technology/...
# 3   https://www.nytimes.com/2008/05/05/business/me...
# 4   https://www.nytimes.com/2008/04/24/technology/...
# ..                                                ...
# 95  https://dealbook.nytimes.com/2008/04/30/at-bea...
# 96  https://bits.blogs.nytimes.com/2007/07/24/the-...
# 97  https://www.nytimes.com/2007/07/09/business/wo...
# 98  https://www.nytimes.com/2007/09/06/business/wo...
# 99  https://www.nytimes.com/2007/07/02/business/me...
#
#                                               snippet  \
# 0   How Steve Jobs used his Apple millions to turn...
# 1   Apple C.E.O. Steve Jobs discusses the new iPho...
# 2   The company announced a new version of the iPh...
# 3   A lot of us carry a little bit of Steve Jobs a...
# 4   Buoyed by unusually strong Macintosh sales, th...
# ..                                                ...
# 95
# 96  AT&T, the exclusive carrier for the iPhone sai...
# 97
# 98
# 99  The Universal Music Group notified Apple that ...
#
#                                        lead_paragraph print_section  \
# 0   Great paradigm-shifting narratives  entrepren...            BR
# 1   Apple C.E.O. Steve Jobs discusses the new iPho...           NaN
# 2   SAN FRANCISCO  Steven P. Jobs, chief executiv...             C
# 3                    I don’t own my iPod. It owns me.             C
# 4   SAN FRANCISCO  Signs of a consumer slowdown a...             C
# ..                                                ...           ...
# 95  Though it has been widely reported that Bear S...           NaN
# 96  There’s no evidence to prove that Steve Jobs d...           NaN
# 97  EVERETT, Washington — Step aside, Steve Jobs. ...           NaN
# 98  SAN FRANCISCO — The chief executive of Apple, ...           NaN
# 99   Steven P. Jobs, the co-founder and chief exec...             C
#
#    print_page                        source  \
# 0          13            The New York Times
# 1         NaN            The New York Times
# 2           4            The New York Times
# 3           1            The New York Times
# 4           1            The New York Times
# ..        ...                           ...
# 95        NaN            The New York Times
# 96        NaN            The New York Times
# 97        NaN  International Herald Tribune
# 98        NaN  International Herald Tribune
# 99          1            The New York Times
#
#                                            multimedia  \
# 0   [{'rank': 0, 'subtype': 'articleInline', 'capt...
# 1   [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 2   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3   [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 4   [{'rank': 0, 'subtype': 'popup', 'caption': No...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                              headline  \
# 0   {'main': 'Success Story 2', 'kicker': None, 'c...
# 1   {'main': 'Apple's iPhone 2.0', 'kicker': None,...
# 2   {'main': 'Apple Aims for the Masses With a Che...
# 3   {'main': 'Steve Jobs Stakes Out the TV Den', '...
# 4   {'main': 'Apple Riding a 51% Jump in Mac Sales...
# ..                                                ...
# 95  {'main': 'At Bear, Letters Bring Good News and...
# 96  {'main': 'The iTease', 'kicker': 'Bits', 'cont...
# 97  {'main': 'Big-time fanfare for a long-distance...
# 98  {'main': 'Apple offers $100 credit to disgrunt...
# 99  {'main': 'Universal in Dispute With Apple Over...
#
#                                              keywords  ...   news_desk  \
# 0   [{'name': 'organizations', 'value': 'Disney, W...  ...  BookReview
# 1   [{'name': 'organizations', 'value': 'Apple Inc...  ...
# 2   [{'name': 'organizations', 'value': 'Apple Inc...  ...    Business
# 3   [{'name': 'subject', 'value': 'DVD (Digital Ve...  ...    Business
# 4   [{'name': 'subject', 'value': 'Company Reports...  ...    Business
# ..                                                ...  ...         ...
# 95                                                 []  ...    Business
# 96                                                 []  ...    Business
# 97                                                 []  ...    IHT News
# 98                                                 []  ...    IHT News
# 99  [{'name': 'organizations', 'value': 'Universal...  ...    Business
#
#     section_name         subsection_name  \
# 0          Books             Book Review
# 1     Technology                     NaN
# 2     Technology                     NaN
# 3   Business Day                   Media
# 4     Technology                     NaN
# ..           ...                     ...
# 95  Business Day                     NaN
# 96    Technology                     NaN
# 97  Business Day  International Business
# 98  Business Day  International Business
# 99  Business Day                   Media
#
#                                                byline type_of_material  \
# 0   {'original': 'By Michael Hirschorn', 'person':...           Review
# 1   {'original': None, 'person': [], 'organization...            Video
# 2   {'original': 'By John Markoff', 'person': [{'f...             News
# 3   {'original': 'By David Carr', 'person': [{'fir...             News
# 4   {'original': 'By John Markoff', 'person': [{'f...             News
# ..                                                ...              ...
# 95  {'original': 'By Dealbook', 'person': [{'first...             News
# 96  {'original': 'By Saul Hansell', 'person': [{'f...             News
# 97  {'original': 'By William Yardley', 'person': [...             News
# 98  {'original': None, 'person': [], 'organization...             News
# 99  {'original': 'By Jeff Leeds', 'person': [{'fir...             News
#
#                                                   _id word_count  \
# 0   nyt://article/eaa284e7-cc8a-53a7-8672-8dbcd0ba...       1268
# 1    nyt://video/cc53239f-df10-5c98-b6ab-6a70a92b0daf          0
# 2   nyt://article/d0434bf5-d120-5ff1-801a-e40c54c0...        848
# 3   nyt://article/c8ef438e-7137-5246-9a9f-249dfefe...       1262
# 4   nyt://article/3eefc4be-e49a-567b-92f2-070059b7...        890
# ..                                                ...        ...
# 95  nyt://article/c0ec6402-66bd-52a2-96b4-1a25e89d...        229
# 96  nyt://article/d289f164-4ae6-5baa-86c1-6027220a...        166
# 97  nyt://article/0ad64571-0389-5d14-a014-5cb1f97b...        558
# 98  nyt://article/c36c780f-4246-5197-b201-4cf115bc...        627
# 99  nyt://article/9ab7a5fe-e47b-5105-a461-d96cc060...       1084
#
#                                                   uri  \
# 0   nyt://article/eaa284e7-cc8a-53a7-8672-8dbcd0ba...
# 1    nyt://video/cc53239f-df10-5c98-b6ab-6a70a92b0daf
# 2   nyt://article/d0434bf5-d120-5ff1-801a-e40c54c0...
# 3   nyt://article/c8ef438e-7137-5246-9a9f-249dfefe...
# 4   nyt://article/3eefc4be-e49a-567b-92f2-070059b7...
# ..                                                ...
# 95  nyt://article/c0ec6402-66bd-52a2-96b4-1a25e89d...
# 96  nyt://article/d289f164-4ae6-5baa-86c1-6027220a...
# 97  nyt://article/0ad64571-0389-5d14-a014-5cb1f97b...
# 98  nyt://article/c36c780f-4246-5197-b201-4cf115bc...
# 99  nyt://article/9ab7a5fe-e47b-5105-a461-d96cc060...
#
#                                                  text sentiment
# 0   How Steve Jobs used his Apple millions to turn...  0.025000
# 1   Apple C.E.O. Steve Jobs discusses the new iPho...  0.149621
# 2   The company announced a new version of the iPh...  0.026629
# 3   A lot of us carry a little bit of Steve Jobs a... -0.027083
# 4   Buoyed by unusually strong Macintosh sales, th...  0.001389
# ..                                                ...       ...
# 95  Though it has been widely reported that Bear S... -0.244048
# 96  AT&T, the exclusive carrier for the iPhone sai... -0.126786
# 97  EVERETT, Washington — Step aside, Steve Jobs. ... -0.391667
# 98  SAN FRANCISCO — The chief executive of Apple, ... -0.187500
# 99  The Universal Music Group notified Apple that ... -0.139286
#
# [100 rows x 22 columns]

# %%
#filtered plot
# better plot
sns.relplot(
    data=df_filtered, 
    x="pub_date", y="sentiment",
    kind="line",
    height=5, aspect=2 
)
